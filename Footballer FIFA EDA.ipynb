# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
fifa = pd.read_csv('Footballer.csv')

# %%
fifa.head(3)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# ...

# %%
fifa.shape
# Out:
# (18207, 89)

# %%
fifa.isnull().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 89, dtype: int64

# %%
fifa.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
fifa['Nationality'].value_counts()
# Out:
# England                 1662
# Germany                 1198
# Spain                   1072
# Argentina                937
# France                   914
#                         ...
# New Caledonia              1
# United Arab Emirates       1
# Guam                       1
# Mauritius                  1
# Lebanon                    1
# Name: Nationality, Length: 164, dtype: int64

# %%
fifa.Nationality.value_counts()[:10]
# Out:
# England        1662
# Germany        1198
# Spain          1072
# Argentina       937
# France          914
# Brazil          827
# Italy           702
# Colombia        618
# Japan           478
# Netherlands     453
# Name: Nationality, dtype: int64

# %%
fifa['Nationality'].value_counts()[:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'Argentina', 'France'], dtype='object')

# %%
plt.figure(figsize=(8,8))
plt.bar(list(fifa['Nationality'].value_counts()[:5].keys()),list(fifa['Nationality'].value_counts()[:5]))
plt.show()

# %%
player_salary = fifa[['Name','Wage']]

# %%
player_salary.head()
# Out:
#                 Name   Wage
# 0           L. Messi  €565K
# 1  Cristiano Ronaldo  €405K
# 2          Neymar Jr  €290K
# 3             De Gea  €260K
# 4       K. De Bruyne  €355K

# %%
plt.figure(figsize=(8,8))
plt.bar(list(player_salary['Name'][:5]),list(player_salary['Wage'].value_counts()[:5].keys()))
plt.show()

# %%
germany = fifa[fifa['Nationality']=='Germany']

# %%
germany.head()
# Out:
#     Unnamed: 0      ID           Name  Age  \
# 11          11  182521       T. Kroos   28
# 18          18  192448  M. ter Stegen   26
# 22          22  167495       M. Neuer   32
# 34          34  178603     M. Hummels   29
# 55          55  222492        L. Sané   22
#
#                                              Photo Nationality  \
# 11  https://cdn.sofifa.org/players/4/19/182521.png     Germany
# 18  https://cdn.sofifa.org/players/4/19/192448.png     Germany
# 22  https://cdn.sofifa.org/players/4/19/167495.png     Germany
# 34  https://cdn.sofifa.org/players/4/19/178603.png     Germany
# 55  https://cdn.sofifa.org/players/4/19/222492.png     Germany
#
#                                    Flag  Overall  Potential  \
# 11  https://cdn.sofifa.org/flags/21.png       90         90
# 18  https://cdn.sofifa.org/flags/21.png       89         92
# 22  https://cdn.sofifa.org/flags/21.png       89         89
# 34  https://cdn.sofifa.org/flags/21.png       88         88
# ...

# %%
germany.sort_values(by='Height',ascending=False).head()
# Out:
#        Unnamed: 0      ID           Name  Age  \
# 1426         1426  199833  L. Unnerstall   27
# 13540       13540  208776    F. Stritzel   24
# 17786       17786  240218   A. Weidinger   21
# 13520       13520  239746   L. Watkowiak   22
# 4542         4542  158657     T. Kessler   32
#
#                                                 Photo Nationality  \
# 1426   https://cdn.sofifa.org/players/4/19/199833.png     Germany
# 13540  https://cdn.sofifa.org/players/4/19/208776.png     Germany
# 17786  https://cdn.sofifa.org/players/4/19/240218.png     Germany
# 13520  https://cdn.sofifa.org/players/4/19/239746.png     Germany
# 4542   https://cdn.sofifa.org/players/4/19/158657.png     Germany
#
#                                       Flag  Overall  Potential  \
# 1426   https://cdn.sofifa.org/flags/21.png       76         78
# 13540  https://cdn.sofifa.org/flags/21.png       62         67
# 17786  https://cdn.sofifa.org/flags/21.png       52         60
# ...

# %%
germany.sort_values(by='Weight',ascending=False)
# Out:
#        Unnamed: 0      ID           Name  Age  \
# 13520       13520  239746   L. Watkowiak   22
# 1426         1426  199833  L. Unnerstall   27
# 210           210  179783    R. Fährmann   29
# 1225         1225  200212       M. Esser   30
# 115           115  212190        N. Süle   22
# ...           ...     ...            ...  ...
# 17946       17946  244862        C. Royo   17
# 17619       17619  244094    L. Langhans   19
# 13254       13254  246328     A. Aidonis   17
# 13255       13255  196921       L. Sowah   25
# 13262       13262  244026        H. Paul   24
#
#                                                 Photo Nationality  \
# 13520  https://cdn.sofifa.org/players/4/19/239746.png     Germany
# 1426   https://cdn.sofifa.org/players/4/19/199833.png     Germany
# 210    https://cdn.sofifa.org/players/4/19/179783.png     Germany
# 1225   https://cdn.sofifa.org/players/4/19/200212.png     Germany
# 115    https://cdn.sofifa.org/players/4/19/212190.png     Germany
# ...

# %%
germany.sort_values(by='Wage',ascending=False)
# Out:
#       Unnamed: 0      ID            Name  Age  \
# 3147        3147  204776     T. Leistner   27
# 5259        5259  235407        S. Özcan   20
# 6615        6615  226050     C. Teuchert   21
# 6376        6376  231110        P. Erras   23
# 6323        6323  190648       S. Sirigu   29
# ...          ...     ...             ...  ...
# 6434        6434  232406       R. Krauße   24
# 5346        5346  188586         J. Flum   30
# 4542        4542  158657      T. Kessler   32
# 4985        4985  227647  M. Mittelstädt   21
# 68            68  188350         M. Reus   29
#
#                                                Photo Nationality  \
# 3147  https://cdn.sofifa.org/players/4/19/204776.png     Germany
# 5259  https://cdn.sofifa.org/players/4/19/235407.png     Germany
# 6615  https://cdn.sofifa.org/players/4/19/226050.png     Germany
# 6376  https://cdn.sofifa.org/players/4/19/231110.png     Germany
# 6323  https://cdn.sofifa.org/players/4/19/190648.png     Germany
# ...

# %%
germany[['Name','Wage']].sort_values(by='Wage',ascending=False).head()
# Out:
#              Name Wage
# 3147  T. Leistner  €9K
# 5259     S. Özcan  €9K
# 6615  C. Teuchert  €9K
# 6376     P. Erras  €9K
# 6323    S. Sirigu  €9K

# %%
fifa.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...
